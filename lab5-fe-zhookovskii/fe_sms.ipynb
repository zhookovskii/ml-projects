# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import pandas as pd

df = pd.read_csv('data/SMS.tsv', sep='\t', header=0)
target = df['class']
df = df.drop('class', axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5572 non-null   object
# dtypes: object(1)
# memory usage: 43.7+ KB

# %%
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt

def plot_words(words_arr, importance_arr):
    pd.Series(
        importance_arr.ravel(), index=words_arr
    ).plot.barh(color=['cyan', 'green'], figsize=(7, 7))
    plt.xlabel('Feature importance')
    plt.show()

count_vectorizer = CountVectorizer()
count_vector = count_vectorizer.fit_transform(df.text)
vocabulary = count_vectorizer.vocabulary_

vocabulary
# Out:
# {'go': 3571,
#  'until': 8084,
#  'jurong': 4374,
#  'point': 5958,
#  'crazy': 2338,
#  'available': 1316,
#  'only': 5571,
#  'in': 4114,
#  'bugis': 1767,
#  'great': 3655,
#  'world': 8548,
#  'la': 4501,
#  'buffet': 1765,
#  'cine': 2061,
#  'there': 7694,
#  'got': 3615,
#  'amore': 1082,
#  'wat': 8324,
#  'ok': 5538,
#  'lar': 4537,
#  'joking': 4342,
#  'wif': 8450,
#  'oni': 5567,
#  'free': 3373,
#  'entry': 2963,
#  'wkly': 8506,
#  'comp': 2178,
#  'to': 7806,
#  'win': 8463,
#  'fa': 3100,
#  'cup': 2398,
#  'final': 3221,
#  'tkts': 7793,
#  '21st': 412,
#  'may': 4959,
#  '2005': 403,
#  'text': 7644,
#  '87121': 794,
#  'receive': 6340,
#  'question': 6232,
#  'std': 7279,
#  'txt': 7986,
#  'rate': 6284,
#  'apply': 1169,
#  '08452810075over18': 77,
#  'dun': 2815,
#  'say': 6679,
#  'so': 7074,
#  'early': 2836,
#  'hor': 3952,
#  'already': 1054,
#  'then': 7688,
#  'nah': 5270,
#  'don': 2724,
#  'think': 7709,
#  'he': 3805,
#  'goes': 3579,
#  'usf': 8130,
#  'lives': 4692,
#  'around': 1220,
#  'here': 3856,
#  'though': 7729,
#  'freemsg': 3380,
#  'hey': 3866,
#  'darling': 2455,
#  'it': 4245,
#  'been': 1475,
#  'week': 8371,
#  'now': 5453,
#  'and': 1097,
#  'no': 5400,
#  'word': 8539,
#  'back': 1363,
#  'like': 4642,
#  'some': 7089,
#  'fun': 3438,
#  'you': 8668,
#  'up': 8086,
#  'for': 3323,
#  'still': 7302,
#  'tb': 7578,
#  'xxx': 8614,
#  'chgs': 2015,
#  'send': 6771,
#  '50': 616,
#  'rcv': 6297,
#  'even': 3012,
#  'my': 5254,
#  'brother': 1737,
#  'is': 4233,
#  'not': 5438,
#  'speak': 7161,
#  'with': 8492,
#  'me': 4968,
#  'they': 7702,
#  'treat': 7916,
#  'aids': 1004,
#  'patent': 5758,
#  'as': 1237,
#  'per': 5801,
#  'your': 8674,
#  'request': 6449,
#  'melle': 4998,
#  'oru': 5628,
#  'minnaminunginte': 5065,
#  'nurungu': 5473,
#  'vettam': 8188,
#  'has': 3779,
#  'set': 6798,
#  'callertune': 1838,
#  'all': 1041,
#  'callers': 1837,
#  'press': 6081,
#  'copy': 2279,
#  'friends': 3397,
#  'winner': 8474,
#  'valued': 8157,
#  'network': 5349,
#  'customer': 2411,
#  'have': 3794,
#  'selected': 6757,
#  'receivea': 6341,
#  '900': 826,
#  'prize': 6113,
#  'reward': 6504,
#  'claim': 2067,
#  'call': 1828,
#  '09061701461': 224,
#  'code': 2133,
#  'kl341': 4464,
#  'valid': 8153,
#  '12': 323,
#  'hours': 3972,
#  'had': 3721,
#  'mobile': 5119,
#  '11': 312,
#  'months': 5159,
#  'or': 5604,
#  'more': 5163,
#  'entitled': 2960,
#  'update': 8091,
#  'the': 7674,
#  'latest': 4551,
#  'colour': 2154,
#  'mobiles': 5120,
#  'camera': 1849,
#  'co': 2122,
#  'on': 5559,
#  '08002986030': 61,
#  'gonna': 3595,
#  'be': 1451,
#  'home': 3925,
#  'soon': 7116,
#  'want': 8303,
#  'talk': 7545,
#  'about': 870,
#  'this': 7718,
#  'stuff': 7369,
#  'anymore': 1136,
#  'tonight': 7844,
#  've': 8172,
#  'cried': 2355,
#  'enough': 2950,
#  'today': 7813,
#  'six': 6978,
#  'chances': 1956,
#  'cash': 1902,
#  'from': 3414,
#  '100': 298,
#  '20': 398,
#  '000': 1,
#  'pounds': 6021,
#  'csh11': 2374,
#  '87575': 799,
#  'cost': 2291,
#  '150p': 352,
#  'day': 2471,
#  '6days': 690,
#  '16': 364,
#  'tsandcs': 7950,
#  'reply': 6442,
#  'hl': 3897,
#  'info': 4149,
#  'urgent': 8109,
#  'won': 8523,
#  'membership': 5004,
#  'our': 5641,
#  'jackpot': 4270,
#  '81010': 747,
#  'www': 8596,
#  'dbuk': 2476,
#  'net': 5343,
#  'lccltd': 4569,
#  'pobox': 5937,
#  '4403ldnw1a7rw18': 565,
#  'searching': 6726,
#  'right': 6516,
#  'words': 8540,
#  'thank': 7661,
#  'breather': 1706,
#  'promise': 6146,
#  'wont': 8530,
#  'take': 7537,
#  'help': 3842,
#  'granted': 3644,
#  'will': 8460,
#  'fulfil': 3434,
#  'wonderful': 8527,
#  'blessing': 1582,
#  'at': 1273,
#  'times': 7771,
#  'date': 2463,
#  'sunday': 7437,
#  'xxxmobilemovieclub': 8615,
#  'use': 8124,
#  'credit': 2345,
#  'click': 2090,
#  'wap': 8308,
#  'link': 4664,
#  'next': 5367,
#  'message': 5022,
#  'http': 3994,
#  'com': 2157,
#  'qjkgighjjgcbl': 6224,
#  'oh': 5533,
#  'watching': 8329,
#  'eh': 2883,
#  'remember': 6409,
#  'how': 3978,
#  'spell': 7176,
#  'his': 3888,
#  'name': 5276,
#  'yes': 8651,
#  'did': 2606,
#  'naughty': 5303,
#  'make': 4878,
#  'wet': 8408,
#  'fine': 3229,
#  'if': 4067,
#  'that': 7670,
#  'way': 8341,
#  'feel': 3171,
#  'its': 4253,
#  'gota': 3616,
#  'england': 2941,
#  'macedonia': 4840,
#  'dont': 2728,
#  'miss': 5081,
#  'goals': 3575,
#  'team': 7590,
#  'news': 5363,
#  'ur': 8105,
#  'national': 5297,
#  '87077': 793,
#  'eg': 2878,
#  'try': 7946,
#  'wales': 8283,
#  'scotland': 6705,
#  '4txt': 608,
#  'ú1': 8711,
#  'poboxox36504w45wq': 5949,
#  'seriously': 6791,
#  'going': 3584,
#  'ha': 3717,
#  'pay': 5770,
#  'first': 3246,
#  'when': 8419,
#  'da': 2428,
#  'stock': 7305,
#  'comin': 2168,
#  'aft': 974,
#  'finish': 3232,
#  'lunch': 4806,
#  'str': 7330,
#  'down': 2750,
#  'lor': 4747,
#  'ard': 1195,
#  'smth': 7057,
#  'ffffffffff': 3191,
#  'alright': 1055,
#  'can': 1853,
#  'meet': 4987,
#  'sooner': 7117,
#  'just': 4376,
#  'forced': 3325,
#  'myself': 5260,
#  'eat': 2848,
#  'slice': 7009,
#  'really': 6322,
#  'hungry': 4014,
#  'tho': 7725,
#  'sucks': 7406,
#  'mark': 4915,
#  'getting': 3531,
#  'worried': 8551,
#  'knows': 4475,
#  'sick': 6927,
#  'turn': 7969,
#  'pizza': 5892,
#  'lol': 4724,
#  'always': 1064,
#  'convincing': 2267,
#  'catch': 1912,
#  'bus': 1787,
#  'are': 1196,
#  'frying': 3422,
#  'an': 1092,
#  'egg': 2880,
#  'tea': 7584,
#  'eating': 2851,
#  'mom': 5140,
#  'left': 4593,
#  'over': 5663,
#  'dinner': 2637,
#  'do': 2688,
#  'love': 4769,
#  'amp': 1084,
#  'we': 8346,
#  're': 6301,
#  'packing': 5689,
#  'car': 1874,
#  'll': 4696,
#  'let': 4614,
#  'know': 4472,
#  'room': 6557,
#  'ahhh': 999,
#  'work': 8541,
#  'vaguely': 8149,
#  'what': 8412,
#  'does': 2700,
#  'wait': 8277,
#  'clear': 2084,
#  'were': 8397,
#  'sure': 7463,
#  'being': 1493,
#  'sarcastic': 6657,
#  'why': 8443,
#  'doesn': 2702,
#  'live': 4688,
#  'us': 8120,
#  'yeah': 8639,
#  'was': 8317,
#  'apologetic': 1156,
#  'fallen': 3125,
#  'out': 5644,
#  'she': 6843,
#  'actin': 915,
#  'spoilt': 7203,
#  'child': 2023,
#  'caught': 1916,
#  'till': 7768,
#  'but': 1794,
#  'doing': 2714,
#  'too': 7849,
#  'badly': 1368,
#  'cheers': 1999,
#  'tell': 7608,
#  'anything': 1142,
#  'fear': 3163,
#  'of': 5511,
#  'fainting': 3117,
#  'housework': 3976,
#  'quick': 6235,
#  'cuppa': 2400,
#  'thanks': 7662,
#  'subscription': 7394,
#  'ringtone': 6525,
#  'uk': 8016,
#  'charged': 1968,
#  'month': 5156,
#  'please': 5917,
#  'confirm': 2222,
#  'by': 1811,
#  'replying': 6443,
#  'yup': 8695,
#  'look': 4735,
#  'timings': 7775,
#  'msg': 5199,
#  'again': 982,
#  'xuhui': 8610,
#  'learn': 4583,
#  '2nd': 466,
#  'her': 3855,
#  'lesson': 4612,
#  '8am': 819,
#  'oops': 5582,
#  'roommate': 6559,
#  'done': 2726,
#  'see': 6743,
#  'letter': 4616,
#  'decide': 2494,
#  'hello': 3839,
#  'saturday': 6670,
#  'texting': 7652,
#  'decided': 2495,
#  'tomo': 7833,
#  'trying': 7948,
#  'invite': 4207,
#  'pls': 5925,
#  'ahead': 998,
#  'watts': 8337,
#  'wanted': 8305,
#  'weekend': 8373,
#  'abiola': 866,
#  'forget': 3331,
#  'need': 5323,
#  'crave': 2335,
#  'most': 5172,
#  'sweet': 7494,
#  'arabian': 1192,
#  'steed': 7286,
#  'mmmmmm': 5109,
#  'yummy': 8690,
#  '07732584351': 30,
#  'rodger': 6547,
#  'burns': 1784,
#  'tried': 7925,
#  'sms': 7052,
#  'nokia': 5410,
#  'camcorder': 1847,
#  '08000930705': 57,
#  'delivery': 2534,
#  'tomorrow': 7835,
#  'who': 8435,
#  'seeing': 6745,
#  'hope': 3943,
#  'man': 4888,
#  'well': 8388,
#  'endowed': 2931,
#  'am': 1066,
#  'lt': 4793,
#  'gt': 3684,
#  'inches': 4118,
#  'calls': 1843,
#  'messages': 5024,
#  'missed': 5083,
#  'didn': 2608,
#  'get': 3523,
#  'hep': 3854,
#  'immunisation': 4097,
#  'nigeria': 5377,
#  'fair': 3118,
#  'hopefully': 3946,
#  'tyler': 7999,
#  'could': 2301,
#  'maybe': 4961,
#  'ask': 1247,
#  'bit': 1559,
#  'stubborn': 7358,
#  'hospital': 3959,
#  'kept': 4421,
#  'telling': 7609,
#  'weak': 8347,
#  'sucker': 7404,
#  'hospitals': 3960,
#  'suckers': 7405,
#  'thinked': 7710,
#  'time': 7770,
#  'saw': 6678,
#  'class': 2076,
#  'gram': 3636,
#  'usually': 8136,
#  'runs': 6600,
#  'half': 3733,
#  'eighth': 2886,
#  'smarter': 7032,
#  'gets': 3527,
#  'almost': 1050,
#  'whole': 8437,
#  'second': 6730,
#  'fyi': 3454,
#  'ride': 6515,
#  'morning': 5167,
#  'crashing': 2334,
#  'place': 5894,
#  'wow': 8567,
#  'never': 5354,
#  'realized': 6320,
#  'embarassed': 2911,
#  'accomodations': 897,
#  'thought': 7730,
#  'liked': 4643,
#  'since': 6952,
#  'best': 1513,
#  'seemed': 6749,
#  'happy': 3768,
#  'cave': 1920,
#  'sorry': 7126,
#  'give': 3552,
#  'offered': 5519,
#  'embarassing': 2912,
#  'ac': 883,
#  'sptv': 7225,
#  'new': 5358,
#  'jersey': 4312,
#  'devils': 2586,
#  'detroit': 2580,
#  'red': 6363,
#  'wings': 8472,
#  'play': 5908,
#  'ice': 4048,
#  'hockey': 3910,
#  'correct': 2284,
#  'incorrect': 4129,
#  'end': 2926,
#  'mallika': 4887,
#  'sherawat': 6850,
#  'yesterday': 8653,
#  'find': 3226,
#  'url': 8116,
#  'congrats': 2228,
#  'year': 8640,
#  'special': 7163,
#  'cinema': 2062,
#  'pass': 5747,
#  'yours': 8678,
#  '09061209465': 219,
#  'suprman': 7461,
#  'matrix3': 4948,
#  'starwars3': 7267,
#  'etc': 3000,
#  'bx420': 1809,
#  'ip4': 4216,
#  '5we': 651,
#  '150pm': 354,
#  'later': 4550,
#  'meeting': 4989,
#  'where': 8423,
#  'reached': 6304,
#  'gauti': 3488,
#  'sehwag': 6754,
#  'odi': 5510,
#  'series': 6789,
#  'pick': 5864,
#  'burger': 1779,
#  'yourself': 8679,
#  'move': 5185,
#  'pain': 5696,
#  'killing': 4446,
#  'good': 3597,
#  'joke': 4338,
#  'girls': 3549,
#  'situation': 6975,
#  'seekers': 6746,
#  'part': 5736,
#  'checking': 1993,
#  'iq': 4222,
#  'roommates': 6560,
#  'took': 7850,
#  'forever': 3328,
#  'come': 2163,
#  'double': 2743,
#  'check': 1989,
#  'hair': 3728,
#  'dresser': 2773,
#  'said': 6626,
#  'wun': 8595,
#  'cut': 2415,
#  'short': 6886,
#  'nice': 5371,
#  'pleased': 5918,
#  'advise': 957,
#  'following': 3305,
#  'recent': 6344,
#  'review': 6502,
#  'mob': 5117,
#  'awarded': 1333,
#  '1500': 351,
#  'bonus': 1623,
#  '09066364589': 267,
#  'song': 7111,
#  'dedicated': 2505,
#  'which': 8429,
#  'dedicate': 2504,
#  'valuable': 8155,
#  'frnds': 3406,
#  'rply': 6576,
#  'complimentary': 2197,
#  'trip': 7926,
#  'eurodisinc': 3006,
#  'trav': 7908,
#  'aco': 911,
#  'entry41': 2964,
#  '1000': 299,
#  'dis': 2649,
#  '18': 369,
#  'morefrmmob': 5164,
#  'shracomorsglsuplt': 6911,
#  '10': 297,
#  'ls1': 4789,
#  '3aj': 524,
#  'hear': 3817,
#  'divorce': 2678,
#  'barbie': 1399,
#  'comes': 2165,
#  'ken': 4419,
#  'plane': 5900,
#  'wah': 8270,
#  'lucky': 4800,
#  'save': 6674,
#  'money': 5147,
#  'hee': 3830,
#  'finished': 3234,
#  'hi': 3870,
#  'babe': 1354,
#  'im': 4085,
#  'wanna': 8301,
#  'something': 7099,
#  'xx': 8611,
#  'performed': 5808,
#  'waiting': 8280,
#  'machan': 4842,
#  'once': 5563,
#  'thats': 7673,
#  'cool': 2272,
#  'gentleman': 3514,
#  'dignity': 2627,
#  'respect': 6469,
#  'peoples': 5800,
#  'very': 8187,
#  'much': 5217,
#  'shy': 6922,
#  'pa': 5685,
#  'operate': 5589,
#  'after': 975,
#  'same': 6642,
#  'looking': 4739,
#  'job': 4327,
#  'ta': 7522,
#  'earn': 2837,
#  'ah': 996,
#  'stop': 7315,
#  'urgnt': 8112,
#  'real': 6313,
#  'yo': 8663,
#  'tickets': 7758,
#  'one': 5565,
#  'jacket': 4269,
#  'used': 8125,
#  'multis': 5226,
#  'started': 7262,
#  'requests': 6450,
#  'came': 1848,
#  'bed': 1468,
#  'coins': 2139,
#  'factory': 3107,
#  'gotta': 3621,
#  'nitros': 5395,
#  'ela': 2891,
#  'kano': 4400,
#  'il': 4079,
#  'download': 2751,
#  'wen': 8391,
#  'stand': 7250,
#  'close': 2097,
#  'another': 1119,
#  'night': 5379,
#  'spent': 7181,
#  'late': 4547,
#  'afternoon': 977,
#  'casualty': 1910,
#  'means': 4975,
#  'haven': 3796,
#  'any': 1133,
#  'stuff42moro': 7370,
#  'includes': 4122,
#  'sheets': 6845,
#  'smile': 7040,
#  'pleasure': 5920,
#  'trouble': 7933,
#  'pours': 6023,
#  'rain': 6258,
#  'sum1': 7428,
#  'hurts': 4024,
#  'becoz': 1466,
#  'someone': 7093,
#  'loves': 4777,
#  'smiling': 7044,
#  'service': 6794,
#  'representative': 6447,
#  '0800': 53,
#  '169': 367,
#  '6031': 657,
#  'between': 1522,
#  '10am': 307,
#  '9pm': 846,
#  'guaranteed': 3688,
#  '5000': 618,
#  'havent': 3797,
#  'planning': 5904,
#  'buy': 1799,
#  'lido': 4627,
#  '530': 637,
#  'show': 6902,
#  'collected': 2148,
#  'simply': 6949,
#  'password': 5754,
#  'mix': 5099,
#  '85069': 780,
#  'verify': 8183,
#  'usher': 8131,
#  'britney': 1727,
#  'fml': 3296,
#  'po': 5935,
#  'box': 1657,
#  '5249': 634,
#  'mk17': 5102,
#  '92h': 831,
#  '450ppw': 575,
#  'telugu': 7614,
#  'movie': 5188,
#  'abt': 878,
#  'loads': 4703,
#  'loans': 4705,
#  'wk': 8502,
#  'hols': 3923,
#  'run': 6598,
#  'forgot': 3336,
#  'hairdressers': 3730,
#  'appointment': 1172,
#  'four': 3354,
#  'shower': 6904,
#  'beforehand': 1482,
#  'cause': 1917,
#  'prob': 6118,
#  'coffee': 2134,
#  'animation': 1106,
#  'nothing': 5443,
#  'else': 2905,
#  'okay': 5539,
#  'price': 6094,
#  'long': 4731,
#  'legal': 4596,
#  'them': 7684,
#  'ave': 1320,
#  'ams': 1088,
#  'gone': 3593,
#  '4the': 606,
#  'driving': 2782,
#  'test': 7638,
#  'yet': 8654,
#  'mean': 4971,
#  'guess': 3694,
#  'gave': 3489,
#  'boston': 1644,
#  'men': 5008,
#  'changed': 1958,
#  'search': 6725,
#  'location': 4708,
#  'nyc': 5484,
#  'cuz': 2422,
#  'signin': 6937,
#  'page': 5692,
#  'says': 6683,
#  'umma': 8023,
#  'life': 4630,
#  'vava': 8169,
#  'lot': 4755,
#  'dear': 2484,
#  'wishes': 8486,
#  'birthday': 1557,
#  'making': 4882,
#  'truly': 7941,
#  'memorable': 5005,
#  'aight': 1006,
#  'hit': 3890,
#  'would': 8563,
#  'ip': 4215,
#  'address': 933,
#  'considering': 2240,
#  'computer': 2203,
#  'isn': 4240,
#  'minecraft': 5059,
#  'server': 6793,
#  'grumpy': 3681,
#  'old': 5551,
#  'people': 5799,
#  'better': 1519,
#  'lying': 4820,
#  'jokes': 4340,
#  'worry': 8553,
#  'busy': 1793,
#  'plural': 5929,
#  'noun': 5450,
#  'research': 6455,
#  'cos': 2289,
#  'things': 7708,
#  'scared': 6689,
#  'mah': 4865,
#  'loud': 4764,
#  'gent': 3512,
#  'contact': 2245,
#  'last': 4544,
#  'weekends': 8374,
#  'draw': 2765,
#  'shows': 6910,
#  '09064012160': 243,
#  'k52': 4383,
#  '12hrs': 334,
#  '150ppm': 356,
#  'wa': 8265,
#  'openin': 5586,
#  'sentence': 6782,
#  'formal': 3340,
#  'anyway': 1145,
#  'juz': 4382,
#  'tt': 7956,
#  'eatin': 2850,
#  'puttin': 6214,
#  'weight': 8379,
#  'haha': 3724,
#  'anythin': 1141,
#  'happened': 3760,
#  'entered': 2953,
#  'cabin': 1816,
#  'boss': 1643,
#  'felt': 3181,
#  'askd': 1248,
#  'invited': 4208,
#  'apartment': 1150,
#  'went': 8394,
#  'specially': 7167,
#  'holiday': 3920,
#  'flights': 3272,
#  'inc': 4116,
#  'operator': 5590,
#  '0871277810910p': 129,
#  'min': 5052,
#  'goodo': 3606,
#  'must': 5245,
#  'friday': 3392,
#  'potato': 6015,
#  'ratio': 6287,
#  'tortilla': 7867,
#  'needed': 5325,
#  'hmm': 3902,
#  'uncle': 8032,
#  'informed': 4152,
#  'paying': 5776,
#  'school': 6695,
#  'directly': 2643,
#  'food': 3313,
#  'private': 6110,
#  '2004': 402,
#  'account': 900,
#  'statement': 7270,
#  '07742676969': 32,
#  '786': 719,
#  'unredeemed': 8076,
#  'points': 5959,
#  '08719180248': 175,
#  'identifier': 4060,
#  '45239': 577,
#  'expires': 3079,
#  '2000': 400,
#  'caller': 1836,
#  '03': 15,
#  'landline': 4524,
#  '09064019788': 249,
#  'box42wr29c': 1669,
#  'apples': 1167,
#  'pairs': 5700,
#  'malarky': 4884,
#  'todays': 7814,
#  'voda': 8234,
#  'numbers': 5470,
#  'ending': 2928,
#  '7548': 711,
#  '350': 512,
#  'award': 1332,
#  'match': 4936,
#  '08712300220': 111,
#  'quoting': 6246,
#  '4041': 549,
#  'standard': 7251,
#  'rates': 6285,
#  'app': 1160,
#  'sao': 6651,
#  'mu': 5215,
#  'predict': 6055,
#  'buying': 1802,
#  'yetunde': 8656,
#  'hasn': 3781,
#  'sent': 6781,
#  'bother': 1647,
#  'sending': 6773,
#  'involve': 4212,
#  'shouldn': 6897,
#  'imposed': 4104,
#  'apologise': 1157,
#  'girl': 3546,
#  'del': 2524,
#  'bak': 1376,
#  'sum': 7427,
#  'lucyxx': 4803,
#  'tmorrow': 7799,
#  'accomodate': 896,
#  'answer': 1122,
#  'sunshine': 7444,
#  'quiz': 6242,
#  'top': 7858,
#  'sony': 7113,
#  'dvd': 2825,
#  'player': 5910,
#  'country': 2307,
#  'algarve': 1034,
#  'ansr': 1121,
#  '82277': 754,
#  'sp': 7148,
#  'tyrone': 8003,
#  'laid': 4516,
#  'dogging': 2708,
#  'locations': 4709,
#  'direct': 2642,
#  'join': 4335,
#  'largest': 4541,
#  'bt': 1753,
#  'txting': 7992,
#  'gravel': 3649,
#  '69888': 685,
#  'nt': 5460,
#  'ec2a': 2853,
#  '31p': 504,
#  'haf': 3723,
#  'msn': 5206,
#  'yijue': 8660,
#  'hotmail': 3967,
#  'him': 3881,
#  'rooms': 6561,
#  'befor': 1480,
#  'activities': 921,
#  'msgs': 5205,
#  'chat': 1979,
#  'svc': 7479,
#  'hardcore': 3770,
#  'services': 6795,
#  '69988': 689,
#  'age': 985,
#  'yr': 8685,
#  'lazy': 4568,
#  'type': 8000,
#  'lect': 4590,
#  'pouch': 6018,
#  'sir': 6964,
#  'mail': 4870,
#  'swt': 7508,
#  'nver': 5478,
#  'tired': 7779,
#  'little': 4687,
#  'lovable': 4768,
#  'persons': 5826,
#  'coz': 2320,
#  'somtimes': 7108,
#  'those': 7726,
#  'occupy': 5503,
#  'biggest': 1539,
#  'their': 7681,
#  'hearts': 3823,
#  'gud': 3690,
#  'ni8': 5369,
#  'open': 5583,
#  'ya': 8624,
#  'dot': 2742,
#  'whats': 8414,
#  'staff': 7242,
#  'taking': 7542,
#  'replied': 6440,
#  'randy': 6278,
#  'sexy': 6811,
#  'female': 3182,
#  'local': 4707,
#  'luv': 4811,
#  'netcollex': 5344,
#  'ltd': 4794,
#  '08700621170150p': 81,
#  'ummma': 8025,
#  'begin': 1486,
#  'qatar': 6219,
#  'pray': 6050,
#  'hard': 3769,
#  'deleted': 2528,
#  'sindu': 6954,
#  'birla': 1553,
#  'soft': 7079,
#  'wine': 8470,
#  'flowing': 3287,
#  'nevering': 5355,
#  'thk': 7719,
#  'plaza': 5915,
#  'typical': 8002,
#  'everywhere': 3030,
#  'dirt': 2646,
#  'floor': 3281,
#  'windows': 8467,
#  'shirt': 6865,
#  'sometimes': 7101,
#  'mouth': 5184,
#  'dream': 2768,
#  'without': 8496,
#  'chores': 2050,
#  ...}

# %% [markdown]
# ## Встроенный метод

# %%
from EmbeddedSelector import EmbeddedSelector
from sklearn.ensemble import RandomForestClassifier

selector = EmbeddedSelector(
    RandomForestClassifier(max_depth=5),
    min_features=30
)

selected = selector.fit_transform(count_vector, target)

words, importance = selector.get_words(vocabulary, return_importance=True)

plot_words(words, importance)

# %%
# all features

score = cross_val_score(
    RandomForestClassifier(max_depth=5), count_vector, target
)
score.mean()
# Out:
# 0.866834338343625

# %%
# selected features

score = cross_val_score(
    RandomForestClassifier(max_depth=5), selected, target
)
score.mean()
# Out:
# 0.9380813293508627

# %% [markdown]
# ## Метод-обертка

# %%
from WrapperSelector import WrapperSelector
from sklearn.linear_model import RidgeClassifier

selector = WrapperSelector(
    RidgeClassifier(),
    min_features=30,
    n_shuffles=10
)

selected = selector.fit_transform(count_vector[:200], target[:200])

words, importance = selector.get_words(vocabulary, return_importance=True)

plot_words(words, importance)
# Out:
# estimated first 0 features
# estimated first 100 features
# estimated first 200 features
# estimated first 300 features
# estimated first 400 features
# estimated first 500 features
# estimated first 600 features
# estimated first 700 features
# estimated first 800 features
# estimated first 900 features
# estimated first 1000 features
# estimated first 1100 features
# estimated first 1200 features
# estimated first 1300 features
# estimated first 1400 features
# estimated first 1500 features
# estimated first 1600 features
# estimated first 1700 features
# estimated first 1800 features
# estimated first 1900 features
# estimated first 2000 features
# estimated first 2100 features
# estimated first 2200 features
# estimated first 2300 features
# estimated first 2400 features
# estimated first 2500 features
# estimated first 2600 features
# estimated first 2700 features
# estimated first 2800 features
# estimated first 2900 features
# estimated first 3000 features
# estimated first 3100 features
# estimated first 3200 features
# estimated first 3300 features
# estimated first 3400 features
# estimated first 3500 features
# estimated first 3600 features
# estimated first 3700 features
# estimated first 3800 features
# estimated first 3900 features
# estimated first 4000 features
# estimated first 4100 features
# estimated first 4200 features
# estimated first 4300 features
# estimated first 4400 features
# estimated first 4500 features
# estimated first 4600 features
# estimated first 4700 features
# estimated first 4800 features
# estimated first 4900 features
# estimated first 5000 features
# estimated first 5100 features
# estimated first 5200 features
# estimated first 5300 features
# estimated first 5400 features
# estimated first 5500 features
# estimated first 5600 features
# estimated first 5700 features
# estimated first 5800 features
# estimated first 5900 features
# estimated first 6000 features
# estimated first 6100 features
# estimated first 6200 features
# estimated first 6300 features
# estimated first 6400 features
# estimated first 6500 features
# estimated first 6600 features
# estimated first 6700 features
# estimated first 6800 features
# estimated first 6900 features
# estimated first 7000 features
# estimated first 7100 features
# estimated first 7200 features
# estimated first 7300 features
# estimated first 7400 features
# estimated first 7500 features
# estimated first 7600 features
# estimated first 7700 features
# estimated first 7800 features
# estimated first 7900 features
# estimated first 8000 features
# estimated first 8100 features
# estimated first 8200 features
# estimated first 8300 features
# estimated first 8400 features
# estimated first 8500 features
# estimated first 8600 features
# estimated first 8700 features

# %%
score = cross_val_score(
    RidgeClassifier(), count_vector[:200], target[:200]
)
score.mean()
# Out:
# 0.9199999999999999

# %%
score = cross_val_score(
    RidgeClassifier(), selected, target[:200]
)
score.mean()
# Out:
# 0.905

# %% [markdown]
# ## Фильтр

# %%
from FilterSelector import FilterSelector
from sklearn.neighbors import KNeighborsClassifier

selector = FilterSelector(min_features=30)

selected = selector.fit_transform(count_vector, target)

words, importance = selector.get_words(vocabulary, return_importance=True)

plot_words(words, importance)

# %%
score = cross_val_score(
    KNeighborsClassifier(n_neighbors=10), count_vector, target
)
score.mean()
# Out:
# 0.8917796330437723

# %%
score = cross_val_score(
    KNeighborsClassifier(n_neighbors=10), selected, target
)
score.mean()
# Out:
# 0.9282131212211479

# %% [markdown]
# ## Библиотечные методы

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(
    estimator=RandomForestClassifier(max_depth=5),
    max_features=30
)

selected = selector.fit_transform(count_vector, target)

inv_vocabulary = {v: k for k, v in vocabulary.items()}
features = selector.get_support(indices=True)
words = []
importance = []
for i in features:
    words.append(inv_vocabulary[i])
    importance.append(selector.estimator_.feature_importances_[i])

plot_words(np.array(words), np.array(importance))

# %%
score = cross_val_score(
    RandomForestClassifier(max_depth=5), count_vector, target
)
score.mean()
# Out:
# 0.8670135495245994

# %%
score = cross_val_score(
    RandomForestClassifier(max_depth=5), selected, target
)
score.mean()
# Out:
# 0.941850560739387

# %%
from sklearn.inspection import permutation_importance

X_train, X_valid, y_train, y_valid = train_test_split(count_vector.toarray()[:200], target[:200], train_size=0.7)

estimator = RidgeClassifier().fit(X_train, y_train)

result = permutation_importance(estimator, X_valid, y_valid, n_repeats=10)
features = np.argsort(result.importances_mean)[-30:]
features = np.array(list(filter(
    lambda x: result.importances_mean[x] != 0,
    features
)))
words = []
importance = []
for i in features:
    words.append(inv_vocabulary[i])
    importance.append(result.importances_mean[i])

plot_words(np.array(words), np.array(importance))

# %%
from sklearn.feature_selection import SelectKBest, chi2

selector = SelectKBest(score_func=chi2, k=30)

selected = selector.fit_transform(count_vector, target)

features = selector.get_support(indices=True)
words = []
importance = []
for i in features:
    words.append(inv_vocabulary[i])
    importance.append(selector.scores_[i])

plot_words(np.array(words), np.array(importance))

# %%
score = cross_val_score(
    RidgeClassifier(), count_vector, target
)
score.mean()
# Out:
# 0.9779248214731385

# %%
score = cross_val_score(
    RidgeClassifier(), selected, target
)
score.mean()
# Out:
# 0.9553110433053433
